# %% [markdown]
# Repositório: https://github.com/maponti/langgraph_shortcourse

# %% [markdown]
# ## Grafo com 1 nó

# %%
# !pip install langgraph
# Out:
# Requirement already satisfied: langgraph in /opt/homebrew/anaconda3/lib/python3.12/site-packages (1.0.3)
# Requirement already satisfied: langchain-core>=0.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langgraph) (1.0.5)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langgraph) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langgraph) (1.0.4)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langgraph) (0.2.9)
# Requirement already satisfied: pydantic>=2.7.4 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langgraph) (2.8.2)
# Requirement already satisfied: xxhash>=3.5.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph) (0.4.43)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph) (24.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph) (8.2.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph) (4.11.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph) (0.27.0)
# Requirement already satisfied: orjson>=3.10.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph) (3.11.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph) (2.20.1)
# Requirement already satisfied: anyio in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (4.2.0)
# Requirement already satisfied: certifi in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (1.0.2)
# Requirement already satisfied: idna in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (3.7)
# Requirement already satisfied: sniffio in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph) (2.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (0.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.5.0)

# %%
from typing import TypedDict, List
from langgraph.graph import StateGraph
from IPython.display import Image, display

# %%
class AgentState(TypedDict):
    message : str

# %%
def primeiro_no(state:AgentState) -> AgentState:
    """Nó que adiciona uma saudação à mensagem de estado do agente"""
    state['message'] = "Olá " + state["message"] + ", tudo bem?"
    return state
