# %% [markdown]
# # Aula 3 - Introdução às Redes Neurais Informadas pela Física (PINNs)

# %% [markdown]
# ## 1. Redes Neurais Informadas pela Física (PINNs)

# %% [markdown]
# O quê pode resolver:
#
# - EDOs, EDPs, EID, EDF, ...
# - Equação de Burger
# - Equação de Schrödinger

# %% [markdown]
# ### Construindo uma Função de Perda Customizada

# %% [markdown]
# ## 2. DeepXDE
# - A Deep Learning Library for Solving Differential Equations

# %% [markdown]
# <!-- # Aula 4 - Implementação de algumas PINNs e o DeepXDE -->
